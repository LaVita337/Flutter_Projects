# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_excel(r'/content/2_30000_20231001.xls')
df.head()
# Out:
#    표제어  동형어 번호  구분  품사 고유어 여부   원어       발음   활용  파생어 ☞(가 보라)  ...  \
# 0  벽계수       0  단어  명사    한자어  碧溪水  벽꼐수/벽께수  NaN  NaN     NaN  ...
# 1  벽난로       0  단어  명사    한자어  壁暖爐      병날로  NaN  NaN     NaN  ...
# 2   벽돌       0  단어  명사    혼종어   甓돌       벽똘  NaN  NaN     NaN  ...
# 3  벽돌담       0  단어  명사    혼종어  甓돌담      벽똘담  NaN  NaN     NaN  ...
# 4  벽돌장       0  단어  명사    혼종어  甓돌張      벽똘짱  NaN  NaN     NaN  ...
#
#   러시아어 부표제어 대역어 러시아어 부표제어 대역어 뜻풀이 영어 부표제어 대역어 영어 부표제어 대역어 뜻풀이 일본어 부표제어 대역어  \
# 0           NaN               NaN         NaN             NaN          NaN
# 1           NaN               NaN         NaN             NaN          NaN
# 2           NaN               NaN         NaN             NaN          NaN
# 3           NaN               NaN         NaN             NaN          NaN
# 4           NaN               NaN         NaN             NaN          NaN
#
#   일본어 부표제어 대역어 뜻풀이 프랑스어 부표제어 대역어 프랑스어 부표제어 대역어 뜻풀이 스페인어 부표제어 대역어  \
# 0              NaN           NaN               NaN           NaN
# 1              NaN           NaN               NaN           NaN
# 2              NaN           NaN               NaN           NaN
# 3              NaN           NaN               NaN           NaN
# 4              NaN           NaN               NaN           NaN
#
#    스페인어 부표제어 대역어 뜻풀이
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 74 columns]

# %%
df = df[['표제어', '관련어']]
df.head()
# Out:
#    표제어  관련어
# 0  벽계수  NaN
# 1  벽난로  NaN
# 2   벽돌  NaN
# 3  벽돌담  NaN
# 4  벽돌장  NaN

# %%
df = df.dropna(subset=['관련어'])
df.head()
# Out:
#     표제어          관련어
# 27   변고   유의어 탈2\n\n
# 51   변방  유의어 변경1\n\n
# 73   변상  유의어 배상2\n\n
# 182  별것  참고어 별거1\n\n
# 183  별것  참고어 별거1\n\n

# %%
# '관련어' 열에서 \n을 제거하는 함수
def remove_example_strings(text):
    # 결측값인 경우 빈 문자열로 반환
    if isinstance(text, str):
        # \n 문자열을 공백으로 대체
        cleaned_text = text.replace('\n', '')
        return cleaned_text
    else:
        return ''

# '관련어' 열에 불용어 처리 적용
df['관련어'] = df['관련어'].apply(remove_example_strings)

# 결과 출력
df.head()
# Out:
#     표제어      관련어
# 27   변고   유의어 탈2
# 51   변방  유의어 변경1
# 73   변상  유의어 배상2
# 182  별것  참고어 별거1
# 183  별것  참고어 별거1

# %%
# 행의 개수 세기
row_count = df.shape[0]

# 결과 출력
print("행의 개수:", row_count)
# Out:
# 행의 개수: 1685

# %%
# '유의어' 포함된 행의 개수 세기
synonym_count = df[df['관련어'].str.contains('유의어')].shape[0]

# '반대말' 포함된 행의 개수 세기
opposite_word_count = df[df['관련어'].str.contains('반대말')].shape[0]

# 결과 출력
print("유의어 포함된 행의 개수:", synonym_count)
print("반대말 포함된 행의 개수:", opposite_word_count)
# Out:
# 유의어 포함된 행의 개수: 620
# 반대말 포함된 행의 개수: 268

# %%
# '유의어' 포함된 행을 df의 형태로 모음
df_synonym = df[df['관련어'].str.contains('유의어')]
# '관련어' 열에서 '유의어'라는 단어 삭제
df_synonym['관련어'] = df_synonym['관련어'].str.replace('유의어', '')

# '반대말' 포함된 행을 df의 형태로 모음
df_opposite = df[df['관련어'].str.contains('반대말')]
# '관련어' 열에서 '반대말'이라는 단어 삭제
df_opposite['관련어'] = df_opposite['관련어'].str.replace('반대말', '')


# df_synonym과 df_opposite 데이터프레임을 각각 출력
display(df_synonym.head())
display(df_opposite.head())
# Out:
# <ipython-input-8-8c49f471d995>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_synonym['관련어'] = df_synonym['관련어'].str.replace('유의어', '')
# <ipython-input-8-8c49f471d995>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_opposite['관련어'] = df_opposite['관련어'].str.replace('반대말', '')
#     표제어   관련어
# 27   변고    탈2
# 51   변방   변경1
# 73   변상   배상2
# 248  별호    호2
# 295  병사   군사1
#       표제어    관련어
# 575   보수적   진보적1
# 576   보수적   진보적2
# 833    복수    단수2
# 1684  부정적   긍정적1
# 1685  부정적   긍정적1

# %%
# '관련어' 열 이름을 '유의어'로 변경
df_synonym = df_synonym.rename(columns={'관련어': '유의어'})

# '관련어' 열 이름을 '반대말'로 변경
df_opposite = df_opposite.rename(columns={'관련어': '반대말'})

# %%
# 중복 행 제거
df_synonym = df_synonym.drop_duplicates()

# 중복 행 제거
df_opposite = df_opposite.drop_duplicates()

# %%
# df_synonym과 df_opposite 데이터프레임을 각각 출력
display(df_synonym.head())
display(df_opposite.head())
# Out:
#     표제어   유의어
# 27   변고    탈2
# 51   변방   변경1
# 73   변상   배상2
# 248  별호    호2
# 295  병사   군사1
#       표제어    반대말
# 575   보수적   진보적1
# 576   보수적   진보적2
# 833    복수    단수2
# 1684  부정적   긍정적1
# 1686  부정적   긍정적2

# %%
# 결과 출력
print("유의어 포함된 행의 개수:", df_synonym.shape[0])
print("반대말 포함된 행의 개수:", df_opposite.shape[0])
# Out:
# 유의어 포함된 행의 개수: 579
# 반대말 포함된 행의 개수: 206
